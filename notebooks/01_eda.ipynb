# %% [markdown]
# # Exploratory Data Analysis (EDA) - SaaS Subscription Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set plotting style
sns.set_theme(style="whitegrid")

# Load raw generated data
df_subs = pd.read_csv('../data/raw/subscriptions.csv')
df_customers = pd.read_csv('../data/raw/customers.csv')
df_usage = pd.read_csv('../data/raw/usage_events.csv')

print("Data Loaded Successfully!")
# Out:
# Data Loaded Successfully!

# %%
# Barplot
sns.barplot(
    x=status_counts.index, 
    y=status_counts.values, 
    hue=status_counts.index,  # Assign x variable to hue
    palette='viridis', 
    legend=False             # Set legend to False to avoid a redundant legend
)
# Out:
# <Axes: xlabel='status'>

# %%
# Aggregate usage per customer
usage_agg = df_usage.groupby('customer_id')['usage_count'].sum().reset_index()

plt.figure(figsize=(8, 5))
sns.histplot(usage_agg['usage_count'], bins=30, kde=True, color='blue')
plt.title("Customer Usage Distribution")
plt.xlabel("Total Usage Events")
plt.show()
